# %% [markdown]
# ## Shubham Jadhav Roll no:-282027
#
# **Assignment 3**
#
# Visualize the data using R/Python by plotting the graphs for previous assignments.
#
# Consider suitable data set.
#
# Use Scatter plot, Bar plot, Box plot, Pie chart, Line Chart.

# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load dataset

# %%
heart = pd.read_csv(r"D:\ML_ASSIGNMENTS\Heart (1).csv")
heart.head()
# Out:
#    Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0           1   63    1       typical     145   233    1        2    150
# 1           2   67    1  asymptomatic     160   286    0        2    108
# 2           3   67    1  asymptomatic     120   229    0        2    129
# 3           4   37    1    nonanginal     130   250    0        0    187
# 4           5   41    0    nontypical     130   204    0        2    172
#
#    ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0      0      2.3      3  0.0       fixed   No
# 1      1      1.5      2  3.0      normal  Yes
# 2      1      2.6      2  2.0  reversable  Yes
# 3      0      3.5      3  0.0      normal   No
# 4      0      1.4      1  0.0      normal   No

# %% [markdown]
# ## Check for missing values

# %%
heart.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
heart.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %% [markdown]
# # Bar Plot

# %%
# Bar Chart: Distribution of Chest Pain Types
plt.figure(figsize=(8, 6))
heart['ChestPain'].value_counts().plot(kind='bar', color='skyblue', edgecolor='black')

# Adding labels and title

plt.title('Distribution of Chest Pain Types', fontsize=16)
plt.xlabel('Chest Pain Type', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(8, 6))
plt.hist(heart['Age'], bins=10, color='green', edgecolor='black', alpha=0.7)

# Adding labels and title
plt.title('Distribution of Age', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # line chart

# %%
age_maxhr = heart.groupby('Age')['MaxHR'].mean()

plt.figure(figsize=(10, 6))
plt.plot(age_maxhr.index, age_maxhr.values, marker='o', color='blue')

# Adding labels and title
plt.title('Average Max Heart Rate by Age', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Max Heart Rate (bpm)', fontsize=14)
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# # pie chart

# %%
ahd_counts = heart['AHD'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(ahd_counts, labels=ahd_counts.index, autopct='%1.1f%%', startangle=140, colors=['orange', 'skyblue'])
plt.title('Proportion of AHD Categories', fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Box Plot

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='AHD', y='Chol', data=heart, palette='coolwarm')

# Adding labels and title
plt.title('Cholesterol Levels by AHD', fontsize=16)
plt.xlabel('Heart Disease (AHD)', fontsize=14)
plt.ylabel('Cholesterol (mg/dL)', fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_37252\221963167.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='AHD', y='Chol', data=heart, palette='coolwarm')

# %% [markdown]
# # scatter plot

# %%
# Scatter Plot: Cholesterol vs MaxHR
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Chol', y='MaxHR', hue='AHD', data=heart, palette='coolwarm', s=100)

# Adding labels and title
plt.title('Cholesterol vs Max Heart Rate', fontsize=16)
plt.xlabel('Cholesterol (mg/dL)', fontsize=14)
plt.ylabel('Max Heart Rate (bpm)', fontsize=14)
plt.legend(title='AHD')
plt.tight_layout()
plt.show()
